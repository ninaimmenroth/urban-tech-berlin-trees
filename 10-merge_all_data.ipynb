# %% [markdown]
# # Merge all the data

# %%
import geopandas as gpd
import pandas as pd

# %%
gdf_trees = gpd.read_file("data/berlin_strassenbaeume.geojson")
gdf_trees.columns
# Out:
# Index(['id', 'gisid', 'pitid', 'standortnr', 'kennzeich', 'namenr',
#        'art_dtsch', 'art_bot', 'gattung_deutsch', 'gattung', 'art_gruppe',
#        'strname', 'hausnr', 'zusatz', 'pflanzjahr', 'standalter', 'kronedurch',
#        'stammumfg', 'baumhoehe', 'eigentuemer', 'bezirk', 'geometry'],
#       dtype='object')

# %%
df_ndvi = pd.read_csv("data/timeseries/ndvi_CWP_2022.csv")
df_water = pd.read_csv("data/timeseries/watering_2022.csv")  
df_weather = pd.read_csv("data/timeseries/weather_features.csv")

# %%
df_ndvi["tree_id"] = df_ndvi["tree_id"].astype(str)
gdf_trees["pitid"] = gdf_trees["pitid"].astype(str)

# %%
# keep only trees which have ndvi
gdf_ndvi_trees = gdf_trees.merge(
    df_ndvi,
    left_on="pitid",
    right_on="tree_id",
    how="inner"
)

# %%
# merge with watering data
df_water = df_water.reset_index()

gdf_ndvi_trees = gdf_ndvi_trees.merge(
    df_water,
    left_on="pitid",
    right_on="id",
    how="left"
)

# %%
# fill missing watering
water_cols = [c for c in gdf_ndvi_trees.columns if c.startswith("water_m")]
gdf_ndvi_trees[water_cols] = gdf_ndvi_trees[water_cols].fillna(0)

# %%
# merge with weather data
gdf_ndvi_trees = gdf_ndvi_trees.merge(
    df_weather,
    how="cross"
)

gdf_ndvi_trees.head(5)
# Out:
#                                id_x              gisid              pitid  \
# 0  strassenbaeume.00008100_000c09d7  00008100_000c09d7  00008100:000c09d7
# 1  strassenbaeume.00008100_000c09e9  00008100_000c09e9  00008100:000c09e9
# 2  strassenbaeume.00008100_000c09ea  00008100_000c09ea  00008100:000c09ea
# 3  strassenbaeume.00008100_000c0a20  00008100_000c0a20  00008100:000c0a20
# 4  strassenbaeume.00008100_000c0a21  00008100_000c0a21  00008100:000c0a21
#
#   standortnr kennzeich            namenr        art_dtsch  \
# 0         48     01380   Friedbergstraße   Echter Rotdorn
# 1         30     01380   Friedbergstraße   Echter Rotdorn
# 2         29     01380   Friedbergstraße   Echter Rotdorn
# 3         49     01362  Fredericiastraße  Fächerblattbaum
# 4         48     01362  Fredericiastraße  Fächerblattbaum
#
#                                 art_bot gattung_deutsch    gattung  ...  \
# 0  Crataegus laevigata 'Paul´s Scarlet'        WEIßDORN  CRATAEGUS  ...
# 1  Crataegus laevigata 'Paul´s Scarlet'        WEIßDORN  CRATAEGUS  ...
# 2  Crataegus laevigata 'Paul´s Scarlet'        WEIßDORN  CRATAEGUS  ...
# 3                         Ginkgo biloba          GINKGO     GINKGO  ...
# 4                         Ginkgo biloba          GINKGO     GINKGO  ...
#
#      temp_m7    temp_m8 temp_m9 precip_m3 precip_m4  precip_m5  precip_m6  \
# 0  20.251613  21.754839   13.72       2.2      38.0       50.1       35.1
# 1  20.251613  21.754839   13.72       2.2      38.0       50.1       35.1
# 2  20.251613  21.754839   13.72       2.2      38.0       50.1       35.1
# 3  20.251613  21.754839   13.72       2.2      38.0       50.1       35.1
# 4  20.251613  21.754839   13.72       2.2      38.0       50.1       35.1
#
#    precip_m7  precip_m8 precip_m9
# 0       44.9       63.4      50.9
# 1       44.9       63.4      50.9
# 2       44.9       63.4      50.9
# 3       44.9       63.4      50.9
# 4       44.9       63.4      50.9
#
# [5 rows x 54 columns]

# %%
gdf_ndvi_trees.columns
# Out:
# Index(['id_x', 'gisid', 'pitid', 'standortnr', 'kennzeich', 'namenr',
#        'art_dtsch', 'art_bot', 'gattung_deutsch', 'gattung', 'art_gruppe',
#        'strname', 'hausnr', 'zusatz', 'pflanzjahr', 'standalter', 'kronedurch',
#        'stammumfg', 'baumhoehe', 'eigentuemer', 'bezirk', 'geometry',
#        'tree_id', 'NDVI_m3', 'NDVI_m4', 'NDVI_m5', 'NDVI_m6', 'NDVI_m7',
#        'NDVI_m8', 'NDVI_m9', 'has_watering', 'index', 'id_y', 'water_m3',
#        'water_m4', 'water_m5', 'water_m6', 'water_m7', 'water_m8', 'water_m9',
#        'temp_m3', 'temp_m4', 'temp_m5', 'temp_m6', 'temp_m7', 'temp_m8',
#        'temp_m9', 'precip_m3', 'precip_m4', 'precip_m5', 'precip_m6',
#        'precip_m7', 'precip_m8', 'precip_m9'],
#       dtype='object')

# %%
# select which columns to keep
keep_cols = (
    # identifiers
    ["pitid", "geometry", "bezirk"] +

    # tree characteristics 
    # Tree taxonomy was included at the functional group, genus, and species level to control for physiological differences affecting vegetation indices.
    ["art_gruppe", "gattung", "art_bot", "pflanzjahr",
     "stammumfg", "baumhoehe", "kronedurch"] +

    # NDVI
    [f"NDVI_m{m}" for m in range(3, 10)] +

    # watering
    [f"water_m{m}" for m in range(3, 10)] +

    # weather
    [f"temp_m{m}" for m in range(3, 10)] +
    [f"precip_m{m}" for m in range(3, 10)] +

    # derived
    ["has_watering"]
)

# %%
missing = set(keep_cols) - set(gdf_ndvi_trees.columns)
assert not missing, f"Missing expected columns: {missing}"

gdf_clean = gdf_ndvi_trees[keep_cols].copy()
gdf_clean.head(5)
# Out:
#                pitid                   geometry                      bezirk  \
# 0  00008100:000c09d7  POINT (13.29195 52.50365)  Charlottenburg-Wilmersdorf
# 1  00008100:000c09e9  POINT (13.29324 52.50396)  Charlottenburg-Wilmersdorf
# 2  00008100:000c09ea  POINT (13.29334 52.50397)  Charlottenburg-Wilmersdorf
# 3  00008100:000c0a20  POINT (13.28022 52.51082)  Charlottenburg-Wilmersdorf
# 4  00008100:000c0a21  POINT (13.28009 52.51081)  Charlottenburg-Wilmersdorf
#
#    art_gruppe    gattung                               art_bot pflanzjahr  \
# 0   Laubbäume  CRATAEGUS  Crataegus laevigata 'Paul´s Scarlet'       1991
# 1   Laubbäume  CRATAEGUS  Crataegus laevigata 'Paul´s Scarlet'       2001
# 2   Laubbäume  CRATAEGUS  Crataegus laevigata 'Paul´s Scarlet'       1991
# 3  Nadelbäume     GINKGO                         Ginkgo biloba       1990
# 4  Nadelbäume     GINKGO                         Ginkgo biloba       1992
#
#    stammumfg  baumhoehe  kronedurch  ...    temp_m8  temp_m9  precip_m3  \
# 0       40.0        7.0         4.0  ...  21.754839    13.72        2.2
# 1       45.0        7.0         4.0  ...  21.754839    13.72        2.2
# 2       60.0        7.0         4.0  ...  21.754839    13.72        2.2
# 3       52.0       12.0         2.0  ...  21.754839    13.72        2.2
# 4       50.0        9.0         3.0  ...  21.754839    13.72        2.2
#
#    precip_m4  precip_m5  precip_m6  precip_m7  precip_m8  precip_m9  \
# 0       38.0       50.1       35.1       44.9       63.4       50.9
# 1       38.0       50.1       35.1       44.9       63.4       50.9
# 2       38.0       50.1       35.1       44.9       63.4       50.9
# 3       38.0       50.1       35.1       44.9       63.4       50.9
# 4       38.0       50.1       35.1       44.9       63.4       50.9
#
#    has_watering
# 0          True
# 1          True
# 2          True
# 3          True
# 4          True
#
# [5 rows x 39 columns]

# %%
# save the data set
gdf_clean.to_file(
    "data/timeseries/trees_ndvi_weather_water_wide.gpkg",
    layer="trees",
    driver="GPKG"
)

# %%
df_long = pd.wide_to_long(
    gdf_clean,
    stubnames=["NDVI", "water", "temp", "precip"],
    i="pitid",
    j="month",
    sep="_m"
).reset_index()

df_long.head()
# Out:
#                pitid  month                               art_bot  art_gruppe  \
# 0  00008100:000c09d7      3  Crataegus laevigata 'Paul´s Scarlet'   Laubbäume
# 1  00008100:000c09e9      3  Crataegus laevigata 'Paul´s Scarlet'   Laubbäume
# 2  00008100:000c09ea      3  Crataegus laevigata 'Paul´s Scarlet'   Laubbäume
# 3  00008100:000c0a20      3                         Ginkgo biloba  Nadelbäume
# 4  00008100:000c0a21      3                         Ginkgo biloba  Nadelbäume
#
#    baumhoehe                      bezirk    gattung  \
# 0        7.0  Charlottenburg-Wilmersdorf  CRATAEGUS
# 1        7.0  Charlottenburg-Wilmersdorf  CRATAEGUS
# 2        7.0  Charlottenburg-Wilmersdorf  CRATAEGUS
# 3       12.0  Charlottenburg-Wilmersdorf     GINKGO
# 4        9.0  Charlottenburg-Wilmersdorf     GINKGO
#
#                     geometry  has_watering  kronedurch pflanzjahr  stammumfg  \
# 0  POINT (13.29195 52.50365)          True         4.0       1991       40.0
# 1  POINT (13.29324 52.50396)          True         4.0       2001       45.0
# 2  POINT (13.29334 52.50397)          True         4.0       1991       60.0
# 3  POINT (13.28022 52.51082)          True         2.0       1990       52.0
# 4  POINT (13.28009 52.51081)          True         3.0       1992       50.0
#
#        NDVI  water      temp  precip
# 0  0.224754    0.0  4.441935     2.2
# 1  0.157686    0.0  4.441935     2.2
# 2  0.180522    0.0  4.441935     2.2
# 3  0.309235    0.0  4.441935     2.2
# 4  0.352739    0.0  4.441935     2.2

# %%
df_long.isna().mean()[["NDVI", "water", "temp", "precip"]]
df_long.groupby("month")["NDVI"].describe()
# Out:
#         count      mean       std       min       25%       50%       75%  \
# month
# 3      1948.0  0.315893  0.108355  0.111629  0.226473  0.302096  0.388796
# 4      1948.0  0.353909  0.123252  0.108144  0.256167  0.341113  0.439573
# 5      1948.0  0.546199  0.160869  0.134627  0.424248  0.555465  0.671565
# 6      1948.0  0.560773  0.165706  0.139899  0.434846  0.566869  0.687145
# 7      1948.0  0.532271  0.163790  0.135340  0.409325  0.531440  0.654966
# 8      1948.0  0.508457  0.166228  0.109063  0.384008  0.508887  0.633166
# 9      1948.0  0.560291  0.157598  0.150561  0.438643  0.565224  0.676985
#
#             max
# month
# 3      0.730605
# 4      0.728687
# 5      0.890362
# 6      0.915398
# 7      0.895193
# 8      0.901977
# 9      0.896729

# %%
# save the data set
df_long.to_file(
    "data/timeseries/trees_ndvi_weather_water_long.gpkg",
    layer="trees",
    driver="GPKG"
)
